# %% [markdown]
# <a href="https://colab.research.google.com/github/zachweiss4/bte320/blob/main/InClassAssingments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hour Fee")
for hour in range(1,9):
  fee=5+2.5*hour
  print(f"{hour}    {fee}")
# Out:
# Hour Fee
# 1    7.5
# 2    10.0
# 3    12.5
# 4    15.0
# 5    17.5
# 6    20.0
# 7    22.5
# 8    25.0
